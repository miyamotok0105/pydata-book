# %%
# import pylab as plt  #どっちでも動く
import matplotlib.pyplot as plt

plt.gca().add_patch( plt.Rectangle(xy=[0.25, 0.25], width=0.5, height=0.5) )
plt.show()

# %%
plt.gca().add_patch( plt.Rectangle(xy=[0.25, 0.25], width=0.5, height=0.5, fill=False) )
plt.show()

# %%
import matplotlib.pyplot as plt

plt.gca().add_patch( plt.Rectangle(xy=[0.25, 0.25], width=0.5, height=0.5, fill=False) )
plt.show()

# %%
plt.gca().add_patch( plt.Rectangle(xy=[0.25, 0.25], width=0.1, height=0.1, linewidth='3.0', fill=False) )
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
# 始点(0.2,0.2)で幅が0.2, 高さが0.4の長方形を描画
rect = plt.Rectangle((0.2,0.2),0.2,0.4,fc="#770000")
ax.add_patch(rect)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt

from skimage import data
from skimage.filters import try_all_threshold

import cv2
import numpy as np

astronaut = data.astronaut()

# %matplotlib inline
print(astronaut.shape)

fig = plt.figure()
ax = fig.add_subplot(111)

rect = plt.Rectangle((198.0, 2.0), 144.0, 270.0 , fc="#770000", fill=False)
ax.add_patch(rect)
# plt.show()
plt.imshow(astronaut)
plt.show()


# # plt.Rectangle(*rect, fill=False, edgecolor=color, linewidth=2))
# plt.Rectangle(*rect, fill=False, linewidth=2)
# rect.add_patch(rect)

    
# plt.imshow(astronaut)
# plt.show()
# Out:
# (512, 512, 3)
