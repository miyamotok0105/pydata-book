# %%
1+1
# Out:
# 2

# %%
a = [1,2,3]

# %% [markdown]
# # イントロスペクション

# %%
a?

# %%
a??

# %%
def aaa():
    print("a")

# %%
aaa?

# %% [markdown]
# # マジックコマンド

# %%
ls
# Out:
# COPYING                        ch07.ipynb
# README.md                      ch08/
# appendix_python.ipynb          ch08.ipynb
# ch02/                          ch09/
# ch02.ipynb                     ch09.ipynb
# ch03/                          ch10.ipynb
# ch04/                          ch11/
# ch04.ipynb                     ch11.ipynb
# ch05/                          ch12.ipynb
# ch05.ipynb                     ch13/
# ch06/                          fec_study.ipynb
# ch06.ipynb                     jupyter notebook sample.ipynb
# ch07/                          nn_sample/

# %%
# %ls
# Out:
# COPYING                        ch07.ipynb
# README.md                      ch08/
# appendix_python.ipynb          ch08.ipynb
# ch02/                          ch09/
# ch02.ipynb                     ch09.ipynb
# ch03/                          ch10.ipynb
# ch04/                          ch11/
# ch04.ipynb                     ch11.ipynb
# ch05/                          ch12.ipynb
# ch05.ipynb                     ch13/
# ch06/                          fec_study.ipynb
# ch06.ipynb                     jupyter notebook sample.ipynb
# ch07/                          nn_sample/

# %%
# %time
# Out:
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 5.01 µs

# %%
# %timeit print("hello")
# Out:
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# ...

# %%
#%run -pで各ファイルごとの時間を出すことができる。プロファイル機能。

# %%
# %history
# Out:
# 1+1
# a = [1,2,3]
# 1+1
# a = [1,2,3]
# a?
# a??
# def aaa():
#     print("a")
# aaa?
# ls
# %ls
# %%ls
# %time
# %timeit print("hello")
# %history
# %history

# %%
# !ls
# Out:
# COPYING                       ch07.ipynb
# README.md                     ch08
# appendix_python.ipynb         ch08.ipynb
# ch02                          ch09
# ch02.ipynb                    ch09.ipynb
# ch03                          ch10.ipynb
# ch04                          ch11
# ch04.ipynb                    ch11.ipynb
# ch05                          ch12.ipynb
# ch05.ipynb                    ch13
# ch06                          fec_study.ipynb
# ch06.ipynb                    jupyter notebook sample.ipynb
# ch07                          nn_sample

# %%
aa = !ls

# %%
aa
# Out:
# ['COPYING',
#  'README.md',
#  'appendix_python.ipynb',
#  'ch02',
#  'ch02.ipynb',
#  'ch03',
#  'ch04',
#  'ch04.ipynb',
#  'ch05',
#  'ch05.ipynb',
#  'ch06',
#  'ch06.ipynb',
#  'ch07',
#  'ch07.ipynb',
#  'ch08',
#  'ch08.ipynb',
#  'ch09',
#  'ch09.ipynb',
#  'ch10.ipynb',
#  'ch11',
#  'ch11.ipynb',
#  'ch12.ipynb',
#  'ch13',
#  'fec_study.ipynb',
#  'jupyter notebook sample.ipynb',
#  'nn_sample']

# %%
# %who
# Out:
# a	 aa	 aaa	 elapsed_time	 i	 start	 time

# %%
import numpy as np

# %%
np.log(a)
# Out:
# array([ 0.        ,  0.69314718,  1.09861229])
